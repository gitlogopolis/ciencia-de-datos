# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/FERNANDO LOPEZ/Documents/base_datos_2008.csv", nrows = 100000) #Número de filas de archivo a leer.

# %%
df.head(10) #Muestra las 10 primeras filas
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
# 5        2110            WN        378  ...    4.0     10.0          0
# 6        1940            WN        509  ...    3.0      7.0          0
# 7        1150            WN        535  ...    7.0      7.0          0
# 8         650            WN         11  ...    6.0     19.0          0
# 9        1655            WN        810  ...    3.0      6.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
# 2               NaN         0           NaN          NaN      NaN
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           2.0          0.0      0.0
# 5               NaN         0           NaN          NaN      NaN
# 6               NaN         0          10.0          0.0      0.0
# 7               NaN         0           NaN          NaN      NaN
# 8               NaN         0           NaN          NaN      NaN
# 9               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            0.0               32.0
# 5            NaN                NaN
# 6            0.0               47.0
# 7            NaN                NaN
# 8            NaN                NaN
# 9            NaN                NaN
#
# [10 rows x 29 columns]

# %%
df.tail() #Muestra las ultimas 5 columnas
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 99995  2008      1          25          5   2204.0        1935    106.0
# 99996  2008      1          26          6   1933.0        1935   2234.0
# 99997  2008      1          27          7   2047.0        1935   2400.0
# 99998  2008      1          28          1   1956.0        1935   2308.0
# 99999  2008      1          29          2   1938.0        1935   2308.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 99995        2257            XE       7676  ...    4.0     17.0          0
# 99996        2257            XE       7676  ...    4.0     16.0          0
# 99997        2257            XE       7676  ...    6.0     18.0          0
# 99998        2257            XE       7676  ...    5.0     25.0          0
# 99999        2257            XE       7676  ...    5.0     41.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 99995               NaN         0           0.0          0.0      0.0
# 99996               NaN         0           NaN          NaN      NaN
# 99997               NaN         0          23.0          0.0      0.0
# 99998               NaN         0           NaN          NaN      NaN
# 99999               NaN         0           NaN          NaN      NaN
#
#        SecurityDelay  LateAircraftDelay
# 99995            0.0              129.0
# 99996            NaN                NaN
# 99997            0.0               40.0
# 99998            NaN                NaN
# 99999            NaN                NaN
#
# [5 rows x 29 columns]

# %%
df.sample(frac = 1) #selecciona aleatoriamente una fracción especificada del número total de filas de 1 a 100%
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 66202  2008      1          23          3    753.0         800    952.0
# 34668  2008      1          13          7   1230.0        1230   1353.0
# 52056  2008      1          19          6   1203.0        1205   1312.0
# 11987  2008      1           7          1   1028.0        1035   1132.0
# 80463  2008      1          28          1    826.0         740    933.0
# ...     ...    ...         ...        ...      ...         ...      ...
# 67486  2008      1          23          3   1037.0        1030   1145.0
# 89300  2008      1          30          3   1441.0        1445   1548.0
# 67875  2008      1          23          3   1019.0        1020   1031.0
# 5983   2008      1           5          6    851.0         850   1121.0
# 91467  2008      1          31          4    701.0         700    811.0
#
#        CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 66202        1005            WN       2553  ...    3.0     12.0          0
# 34668        1355            WN         81  ...    6.0     15.0          0
# 52056        1320            WN       3406  ...    6.0      6.0          0
# 11987        1145            WN       2707  ...    3.0     10.0          0
# 80463         850            WN        255  ...    3.0      7.0          0
# ...           ...           ...        ...  ...    ...      ...        ...
# 67486        1140            WN       3394  ...    3.0     11.0          0
# 89300        1600            WN       1482  ...    5.0      9.0          0
# 67875        1035            WN       1359  ...    9.0      7.0          0
# 5983         1120            WN        755  ...    4.0     10.0          0
# 91467         820            WN       1178  ...    4.0     16.0          0
#
#        CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 66202               NaN         0           NaN          NaN      NaN
# 34668               NaN         0           NaN          NaN      NaN
# 52056               NaN         0           NaN          NaN      NaN
# 11987               NaN         0           NaN          NaN      NaN
# 80463               NaN         0          14.0          0.0      0.0
# ...                 ...       ...           ...          ...      ...
# 67486               NaN         0           NaN          NaN      NaN
# 89300               NaN         0           NaN          NaN      NaN
# 67875               NaN         0           NaN          NaN      NaN
# 5983                NaN         0           NaN          NaN      NaN
# 91467               NaN         0           NaN          NaN      NaN
#
#        SecurityDelay  LateAircraftDelay
# 66202            NaN                NaN
# 34668            NaN                NaN
# 52056            NaN                NaN
# 11987            NaN                NaN
# 80463            0.0               29.0
# ...              ...                ...
# 67486            NaN                NaN
# 89300            NaN                NaN
# 67875            NaN                NaN
# 5983             NaN                NaN
# 91467            NaN                NaN
#
# [100000 rows x 29 columns]

# %%
df = df.sample(frac = 1)

# %%
df.columns  #Muestra las columnas que tiene el data set
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
df.DepTime  #Hora real de salida
# Out:
# 0        2003.0
# 1         754.0
# 2         628.0
# 3         926.0
# 4        1829.0
#           ...
# 99995    2204.0
# 99996    1933.0
# 99997    2047.0
# 99998    1956.0
# 99999    1938.0
# Name: DepTime, Length: 100000, dtype: float64

# %%
df.dtypes #Retorna tipo de datos de cada columna del DataFrame (DF)
# Out:
# Year                   int64
# Month                  int64
# DayofMonth             int64
# DayOfWeek              int64
# DepTime              float64
# CRSDepTime             int64
# ArrTime              float64
# CRSArrTime             int64
# UniqueCarrier         object
# FlightNum              int64
# TailNum               object
# ActualElapsedTime    float64
# CRSElapsedTime         int64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin                object
# Dest                  object
# Distance               int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled              int64
# CancellationCode      object
# Diverted               int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# dtype: object

# %%
df2 = df.head(10)

# %%
df2.head(20)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
# 6  2008      1           3          4   1937.0        1830   2037.0
# 7  2008      1           3          4   1039.0        1040   1132.0
# 8  2008      1           3          4    617.0         615    652.0
# 9  2008      1           3          4   1620.0        1620   1639.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
# 5        2110            WN        378  ...    4.0     10.0          0
# 6        1940            WN        509  ...    3.0      7.0          0
# 7        1150            WN        535  ...    7.0      7.0          0
# 8         650            WN         11  ...    6.0     19.0          0
# 9        1655            WN        810  ...    3.0      6.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
# 2               NaN         0           NaN          NaN      NaN
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           2.0          0.0      0.0
# 5               NaN         0           NaN          NaN      NaN
# 6               NaN         0          10.0          0.0      0.0
# 7               NaN         0           NaN          NaN      NaN
# 8               NaN         0           NaN          NaN      NaN
# 9               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            0.0               32.0
# 5            NaN                NaN
# 6            0.0               47.0
# 7            NaN                NaN
# 8            NaN                NaN
# 9            NaN                NaN
#
# [10 rows x 29 columns]

# %%
df.values #Devuelve una representación Numpy del DataFrame
# Out:
# array([[2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        [2008, 1, 3, ..., nan, nan, nan],
#        ...,
#        [2008, 1, 27, ..., 0.0, 0.0, 40.0],
#        [2008, 1, 28, ..., nan, nan, nan],
#        [2008, 1, 29, ..., nan, nan, nan]], dtype=object)
