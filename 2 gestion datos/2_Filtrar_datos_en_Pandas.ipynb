# %% [markdown]
# <a href="https://colab.research.google.com/github/gitlogopolis/ciencia-de-datos/blob/main/2_Filtrar_datos_en_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5aead171-07bd-455b-b47c-e9f933daf28a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5aead171-07bd-455b-b47c-e9f933daf28a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2008-3.csv to 2008-3.csv

# %%
df = pd.read_csv("2008-3.csv")

# %%
df['ArrDelay'].head() #Muestra los primeros datos de la columna "Arrdelay"
# Out:
# 0   -14.0
# 1     2.0
# 2    14.0
# 3    -6.0
# 4    34.0
# Name: ArrDelay, dtype: float64

# %%
df[100:110]  #Muestra un rango de datos de la fila 100 a la 110
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 100  2008      1           3          4    826.0         825    930.0
# 101  2008      1           3          4   2118.0        2015   2224.0
# 102  2008      1           3          4   1818.0        1740   1916.0
# 103  2008      1           3          4    650.0         650    748.0
# 104  2008      1           3          4   2146.0        2055   2250.0
# 105  2008      1           3          4   2241.0        1910   2340.0
# 106  2008      1           3          4   1409.0        1355   1513.0
# 107  2008      1           3          4   1100.0        1050   1157.0
# 108  2008      1           3          4   1306.0        1250   1406.0
# 109  2008      1           3          4   1726.0        1630   1832.0
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 100         925            WN        136  ...    2.0     16.0          0
# ...

# %%
df[df["ArrDelay"] > 60].head() #Muestra vuelos retrasados mas de 60 secs
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 11  2008      1           3          4   1644.0        1510   1845.0
# 30  2008      1           3          4   2107.0        1945   2334.0
# 37  2008      1           3          4   1812.0        1650   1927.0
# 49  2008      1           3          4   2245.0        1730   2354.0
# 77  2008      1           3          4    958.0         900   1052.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 11        1725            WN       1333  ...    6.0      8.0          0
# 30        2230            WN        362  ...    6.0      7.0          0
# 37        1815            WN        422  ...    6.0     11.0          0
# 49        1850            WN        186  ...    3.0      7.0          0
# 77         950            WN       1574  ...    4.0     14.0          0
#
#     CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[(df["Origin"] == "ATL") & (df["ArrDelay"] > 60)].head()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 109189  2008      1          31          4   1217.0        1210   1511.0
# 110375  2008      1          19          6   1241.0        1215   1735.0
# 121229  2008      1           3          4   1421.0        1200   1526.0
# 132768  2008      1           6          7   1315.0        1130   1410.0
# 133549  2008      1           7          1   2040.0        1800   2156.0
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 109189        1335            XE       2023  ...   21.0     60.0          0
# 110375        1437            XE       1284  ...   12.0    178.0          0
# 121229        1325            XE       2132  ...    9.0     13.0          0
# 132768        1240            YV       7267  ...    3.0      6.0          0
# 133549        1932            YV       2626  ...   12.0     28.0          0
#
# ...

# %%
df[df.Origin.isin(["HOU","ATL"])].head() #Muestra los primeros 5 registros con valores en la columna Origin de HOU y ATL
# Out:
#       Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 3269  2008      1           4          5   1910.0        1910   2025.0
# 3270  2008      1           4          5   1345.0        1345   1453.0
# 3271  2008      1           4          5    736.0         735    839.0
# 3272  2008      1           4          5   1603.0        1550   1647.0
# 3273  2008      1           4          5   2105.0        2105   2151.0
#
#       CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 3269        2025            WN        823  ...    6.0     11.0          0
# 3270        1500            WN        901  ...    3.0     14.0          0
# 3271         850            WN        957  ...    3.0      9.0          0
# 3272        1635            WN        231  ...    5.0     10.0          0
# 3273        2150            WN        570  ...    7.0     11.0          0
#
#       CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
df[pd.isna(df["ArrDelay"])].head() #Muestra las primeras 5 registros donde no hay datos en la columna ArrDelay
# Out:
#      Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 178  2008      1           3          4      NaN         700      NaN
# 373  2008      1           3          4      NaN        1100      NaN
# 399  2008      1           3          4      NaN         905      NaN
# 401  2008      1           3          4      NaN        1620      NaN
# 415  2008      1           3          4      NaN        1930      NaN
#
#      CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 178         830            WN        126  ...    NaN      NaN          1
# 373        1215            WN       1146  ...    NaN      NaN          1
# 399        1025            WN        469  ...    NaN      NaN          1
# 401        1740            WN        618  ...    NaN      NaN          1
# 415        2035            WN       2528  ...    NaN      NaN          1
#
#      CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
len(df[pd.isna(df["ArrDelay"])]) #retorna el numero de filas donde no hay registros en la columna ArrDelay
# Out:
# 16367
