# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/FERNANDO LOPEZ/Documents/base_datos_2008.csv", nrows=100000)

# %%
data = np.unique(df.Cancelled, return_counts=True) #Procedemos a crear un tabla resumen de los vuelos cancelados

# %%
data
# Out:
# (array([0, 1], dtype=int64), array([98858,  1142], dtype=int64))

# %%
plt.pie(x=data[1], labels=data[0], colors= ["red","Green"], startangle=90,radius=2)
plt.show()
